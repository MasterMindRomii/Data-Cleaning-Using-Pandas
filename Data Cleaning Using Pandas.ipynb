# %% [markdown]
# ## Import Neccessary Libraries

# %%
import pandas as pd

# %% [markdown]
# ## Load the Dataset

# %%
df=pd.read_csv('D:\Pandas\laptopData.csv')

# %% [markdown]
# #### Here are all formats that pandas support to load files[CSV, Excel(XLS, XLSX), JSON, HTML, SQL, Clipboard, Feather, Parquet, ORC, SAS, SPSS, STATA, Google BigQuery]

# %% [markdown]
# ## Before Cleaning Process Checking Information about Dataset

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName Inches                    ScreenResolution  \
# 0         0.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1         1.0   Apple  Ultrabook   13.3                            1440x900
# 2         2.0      HP   Notebook   15.6                   Full HD 1920x1080
# 3         3.0   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4         4.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %% [markdown]
# #### head(): This method displays the first few rows of DataFrame, allowing us to get a quick glimpse of data.

# %%
df.describe()
# Out:
#         Unnamed: 0          Price
# count  1273.000000    1273.000000
# mean    652.674784   59955.814073
# std     376.493027   37332.251005
# min       0.000000    9270.720000
# 25%     327.000000   31914.720000
# 50%     652.000000   52161.120000
# 75%     980.000000   79333.387200
# max    1302.000000  324954.720000

# %% [markdown]
# #### describe(): This method generates descriptive statistics for **numerical** columns in DataFrame, such as count, mean, standard deviation, minimum, and maximum values.

# %%
df.shape
# Out:
# (1303, 12)

# %% [markdown]
# #### shape: This attribute returns a tuple representing the dimensions of your DataFrame (rows, columns). It helps us understand the size of dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1273 non-null   float64
#  1   Company           1273 non-null   object
#  2   TypeName          1273 non-null   object
#  3   Inches            1273 non-null   object
#  4   ScreenResolution  1273 non-null   object
#  5   Cpu               1273 non-null   object
#  6   Ram               1273 non-null   object
#  7   Memory            1273 non-null   object
#  8   Gpu               1273 non-null   object
#  9   OpSys             1273 non-null   object
#  10  Weight            1273 non-null   object
#  11  Price             1273 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 122.3+ KB

# %% [markdown]
# #### info(): This method provides a concise summary of DataFrame, including the number of entries, column data types, and memory usage. It's useful for understanding the overall structure of data.

# %% [markdown]
# #### Note: when a column is identified as having the data type 'object', it typically means that the column contains string values or a mixture of different data types. The 'object' data type in pandas is a catch-all for any non-numeric data.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %% [markdown]
# #### columns: This attribute returns the column labels of the DataFrame, allowing us to inspect the column names.

# %%
df.isnull()
# Out:
#       Unnamed: 0  Company  TypeName  Inches  ScreenResolution    Cpu    Ram  \
# 0          False    False     False   False             False  False  False
# 1          False    False     False   False             False  False  False
# 2          False    False     False   False             False  False  False
# 3          False    False     False   False             False  False  False
# 4          False    False     False   False             False  False  False
# ...          ...      ...       ...     ...               ...    ...    ...
# 1298       False    False     False   False             False  False  False
# 1299       False    False     False   False             False  False  False
# 1300       False    False     False   False             False  False  False
# 1301       False    False     False   False             False  False  False
# 1302       False    False     False   False             False  False  False
#
#       Memory    Gpu  OpSys  Weight  Price
# ...

# %% [markdown]
# #### isnull(): This method returns a DataFrame of boolean values indicating whether each element is missing or not. We can use it to identify missing values in dataset.

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          30
# Company             30
# TypeName            30
# Inches              30
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# dtype: int64

# %% [markdown]
# #### df.isnull().sum() calculates the total number of missing values in each column of the DataFrame df.

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1047
# No OS             63
# Linux             61
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            1
# Name: OpSys, dtype: int64

# %% [markdown]
# #### value_counts():It counts the occurrences of each unique value in the Series and returns a new Series with the counts, indexed by the unique values.

# %%
df['OpSys'].unique()
# Out:
# array(['macOS', 'No OS', 'Windows 10', 'Mac OS X', nan, 'Linux',
#        'Windows 10 S', 'Chrome OS', 'Windows 7', 'Android'], dtype=object)

# %% [markdown]
# ####  unique(): This method returns an array of unique values in a column. It helps us identify the distinct values present in data.

# %% [markdown]
# # Let's Start with Data Cleaning

# %% [markdown]
# ## 1. Cleaning Empty Cells

# %% [markdown]
# #### Shape of DataFrame before cleaning of empty cell

# %%
df.shape
# Out:
# (1303, 12)

# %% [markdown]
# #### Shape before dropna()

# %%
#df.dropna(inplace=True)

# %% [markdown]
# #### dropna() : It is used to delete all the rows which contains empty values, inplace=True : It is used to update in existing table, not making new table after dropna() operation.

# %%
df.shape
# Out:
# (1303, 12)

# %% [markdown]
# #### Shape after dropna()

# %% [markdown]
# ## 2. Replace Empty Cells

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.fillna(999)
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %% [markdown]
# #### fillna(): It will add **999** at entire table where columns contains Nan Values.
# #### df['Column_Name'].fillna() : It is also used to fill null values but for specified columns

# %% [markdown]
# ## Replacing using Mean(), Median() and Mode()

# %%
x=df['Price'].mean()
df['Price'].fillna(x)
# Out:
# 0        71378.6832
# 1        47895.5232
# 2        30636.0000
# 3       135195.3360
# 4        96095.8080
#            ...
# 1298     33992.6400
# 1299     79866.7200
# 1300     12201.1200
# 1301     40705.9200
# 1302     19660.3200
# Name: Price, Length: 1303, dtype: float64

# %%
x=df['Price'].median()
df['Price'].fillna(x)
# Out:
# 0        71378.6832
# 1        47895.5232
# 2        30636.0000
# 3       135195.3360
# 4        96095.8080
#            ...
# 1298     33992.6400
# 1299     79866.7200
# 1300     12201.1200
# 1301     40705.9200
# 1302     19660.3200
# Name: Price, Length: 1303, dtype: float64

# %%
x=df['Price'].mode()
df['Price'].fillna(x)
# Out:
# 0        71378.6832
# 1        47895.5232
# 2        30636.0000
# 3       135195.3360
# 4        96095.8080
#            ...
# 1298     33992.6400
# 1299     79866.7200
# 1300     12201.1200
# 1301     40705.9200
# 1302     19660.3200
# Name: Price, Length: 1303, dtype: float64

# %% [markdown]
# ## Cleaning Data in Wrong Format

# %% [markdown]
# #### We have data in proper format so we will not cover it ! but take a look on data wrong format example

# %%
# df['date']=pd.to_datetime(df['date'])

# %% [markdown]
# ## Fixing Wrong Data

# %%
df['Price']
# Out:
# 0        71378.6832
# 1        47895.5232
# 2        30636.0000
# 3       135195.3360
# 4        96095.8080
#            ...
# 1298     33992.6400
# 1299     79866.7200
# 1300     12201.1200
# 1301     40705.9200
# 1302     19660.3200
# Name: Price, Length: 1303, dtype: float64

# %% [markdown]
# #### If i want to change index no 3rd data which i'm treating as wrong data then check below how to solve

# %%
df.loc[3,'Price']=89865.456

# %% [markdown]
# #### It update the value of 3rd index with 89865.456 and we can also use here conditions using python basics just like make 25000 if Price > 70000 like that see below

# %%
for x in df.index:
    if df.loc[x,'Price']<40000:
        df.drop(x,inplace=True)

# %% [markdown]
# #### This Conditional code drop all the records where price is less than 40k

# %%
df['Price']
# Out:
# 0        71378.6832
# 1        47895.5232
# 3        89865.4560
# 4        96095.8080
# 6       114017.6016
#            ...
# 1287     40705.9200
# 1293     47898.7200
# 1295     42943.1472
# 1299     79866.7200
# 1301     40705.9200
# Name: Price, Length: 849, dtype: float64

# %% [markdown]
# #### For Verify : Check the output lenght of just above and above the condition code

# %% [markdown]
# ## Remove Duplicates

# %%
print(df.duplicated())
# Out:
# 0       False
# 1       False
# 3       False
# 4       False
# 6       False
#         ...
# 1287    False
# 1293    False
# 1295    False
# 1299    False
# 1301    False
# Length: 849, dtype: bool

# %%
df.drop_duplicates()
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# 6            6.0   Apple           Ultrabook   15.4
# ...          ...     ...                 ...    ...
# 1287      1287.0      HP            Notebook   15.6
# 1293      1293.0  Lenovo            Notebook   15.6
# 1295      1295.0    Dell            Notebook   15.6
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1301      1301.0      HP            Notebook   15.6
#
#                                 ScreenResolution                          Cpu  \
# 0             IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz
# 1                                       1440x900         Intel Core i5 1.8GHz
# 3             IPS Panel Retina Display 2880x1800         Intel Core i7 2.7GHz
# ...

# %% [markdown]
# ## Data Correlations

# %%
df[['Inches','Price']].corr()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22188\3930614375.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[['Inches','Price']].corr()
#        Price
# Price    1.0

# %% [markdown]
# #### 1 Means there is relationship between columns and -1 means no relationship

# %% [markdown]
# ## Adding a new column in Dataframe

# %%
df['new']=5

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName Inches                    ScreenResolution  \
# 0         0.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1         1.0   Apple  Ultrabook   13.3                            1440x900
# 3         3.0   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4         4.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 6         6.0   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
#
#                     Cpu   Ram               Memory  \
# 0  Intel Core i5 2.3GHz   8GB            128GB SSD
# 1  Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 3  Intel Core i7 2.7GHz  16GB            512GB SSD
# 4  Intel Core i5 3.1GHz   8GB            256GB SSD
# 6  Intel Core i7 2.2GHz  16GB  256GB Flash Storage
#
#                             Gpu     OpSys  Weight        Price  new
# 0  Intel Iris Plus Graphics 640     macOS  1.37kg   71378.6832    5
# ...

# %% [markdown]
# ## Deleting a column in Dataframe

# %%
df.drop(['new'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName Inches                    ScreenResolution  \
# 0         0.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1         1.0   Apple  Ultrabook   13.3                            1440x900
# 3         3.0   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4         4.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 6         6.0   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
#
#                     Cpu   Ram               Memory  \
# 0  Intel Core i5 2.3GHz   8GB            128GB SSD
# 1  Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 3  Intel Core i7 2.7GHz  16GB            512GB SSD
# 4  Intel Core i5 3.1GHz   8GB            256GB SSD
# 6  Intel Core i7 2.2GHz  16GB  256GB Flash Storage
#
#                             Gpu     OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640     macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000     macOS  1.34kg   47895.5232
# ...

# %% [markdown]
# ## Adding a new row in Dataframe

# %%
a=pd.DataFrame({'Company':'Romi'},index=[0])

# %%
a.head()
# Out:
#   Company
# 0    Romi

# %%
df=pd.concat([a,df])

# %%
df.head()
# Out:
#   Company  Unnamed: 0   TypeName Inches                    ScreenResolution  \
# 0    Romi         NaN        NaN    NaN                                 NaN
# 0   Apple         0.0  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1   Apple         1.0  Ultrabook   13.3                            1440x900
# 3   Apple         3.0  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4   Apple         4.0  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                     Cpu   Ram               Memory  \
# 0                   NaN   NaN                  NaN
# 0  Intel Core i5 2.3GHz   8GB            128GB SSD
# 1  Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 3  Intel Core i7 2.7GHz  16GB            512GB SSD
# 4  Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight       Price
# 0                           NaN    NaN     NaN         NaN
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg  71378.6832
# ...

# %% [markdown]
# ## Deletion a row in Dataframe

# %%
df.drop(0,inplace=True)

# %%
df.head()
# Out:
#   Company  Unnamed: 0   TypeName Inches                    ScreenResolution  \
# 1   Apple         1.0  Ultrabook   13.3                            1440x900
# 3   Apple         3.0  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4   Apple         4.0  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 6   Apple         6.0  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 7   Apple         7.0  Ultrabook   13.3                            1440x900
#
#                     Cpu   Ram               Memory  \
# 1  Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 3  Intel Core i7 2.7GHz  16GB            512GB SSD
# 4  Intel Core i5 3.1GHz   8GB            256GB SSD
# 6  Intel Core i7 2.2GHz  16GB  256GB Flash Storage
# 7  Intel Core i5 1.8GHz   8GB  256GB Flash Storage
#
#                             Gpu     OpSys  Weight        Price
# 1        Intel HD Graphics 6000     macOS  1.34kg   47895.5232
# 3            AMD Radeon Pro 455     macOS  1.83kg   89865.4560
# ...

# %% [markdown]
# ## Slicing in Pandas

# %%
df[23:30] # Start and End Points
# Out:
#    Company  Unnamed: 0            TypeName Inches  \
# 41    Dell        41.0              Gaming   15.6
# 44    Dell        44.0  2 in 1 Convertible   17.3
# 45   Apple        45.0           Ultrabook   13.3
# 46     NaN         NaN                 NaN    NaN
# 47    Asus        47.0              Gaming   17.3
# 50     NaN         NaN                 NaN    NaN
# 51    Acer        51.0            Notebook   15.6
#
#                       ScreenResolution                          Cpu   Ram  \
# 41         IPS Panel Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz  16GB
# 44     Full HD / Touchscreen 1920x1080   Intel Core i5 8250U 1.6GHz  12GB
# 45  IPS Panel Retina Display 2560x1600         Intel Core i5 2.0GHz   8GB
# 46                                 NaN                          NaN   NaN
# 47                   Full HD 1920x1080          AMD Ryzen 1700 3GHz   8GB
# 50                                 NaN                          NaN   NaN
# ...

# %%
df[23:30:3] # Start,End and Stop
# Out:
#    Company  Unnamed: 0  TypeName Inches             ScreenResolution  \
# 41    Dell        41.0    Gaming   15.6  IPS Panel Full HD 1920x1080
# 46     NaN         NaN       NaN    NaN                          NaN
# 51    Acer        51.0  Notebook   15.6  IPS Panel Full HD 1920x1080
#
#                             Cpu   Ram                Memory  \
# 41  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 46                          NaN   NaN                   NaN
# 51   Intel Core i7 8550U 1.8GHz   8GB             256GB SSD
#
#                         Gpu       OpSys  Weight     Price
# 41  Nvidia GeForce GTX 1060  Windows 10  2.65kg  79866.72
# 46                      NaN         NaN     NaN       NaN
# 51     Nvidia GeForce MX150  Windows 10   2.2kg  44808.48

# %%
df[['Price']][34:56:5]
# Out:
#        Price
# 61  46833.12
# 71  50882.40
# 79  52054.56
# 88  77202.72
# 95  45128.16
